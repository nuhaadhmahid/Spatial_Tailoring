# %%
import Utils
from Fairing import FairingData

import os

case_name = "test_case_10"
case_number = 1
data_file = os.path.join(case_name, "data", f"{case_number}_fairing_data")

fairing_data = Utils.ReadWriteOps.load_object(data_file, "pickle")

for key in fairing_data.__dict__.keys():
    print(f"{key}: {len(fairing_data.__dict__[key])}")
# Out:
# dict_keys(['case_folder', 'case_number', 'hinge_node', 'surface_nodes_U', 'shell_equivalent_SE', 'shell_equivalent_SK'])
